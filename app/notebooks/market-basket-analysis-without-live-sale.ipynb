# %%
import pandas as pd
import json
import ast
import plotly.express as px
import math

# %%
jamstones = pd.read_csv('jamstones.csv')
lavval = pd.read_csv('lavval.csv')
newagefsg = pd.read_csv('newage.csv')

# %%
# Preprocessing

#helper functions
def trim_all_columns(df):
    """
    Trim whitespace from ends of each value across all series in dataframe
    """
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)
    
def check_format(row):
    if type(row)==str:
        if ((row[0] == '['and row[len(row)-1] == ']' and row[1] == '{'and row[len(row)-2] == '}') or (row[0] == '{'and row[len(row)-1] == '}') )and len(row)>10:
            return True
    else:
        return False

def preprocessing(df):
    df_copy = df.copy()[['id','line_items']]
    df_copy.dropna(inplace = True)
    
    df_copy = trim_all_columns(df_copy)
    df_copy.line_items = df_copy.line_items.apply(eval).apply(json.dumps)

    def clean_json(x):
        "Create apply function for decoding JSON"
        return json.loads(x)

    df_copy['line_items'] = df_copy['line_items'].apply(clean_json)  
    
    return df_copy

# %%
jamstones_preprocessed = preprocessing(jamstones)
lavval_preprocessed = preprocessing(lavval)
newagefsg_preprocessed = preprocessing(newagefsg)
items_df = pd.concat([jamstones_preprocessed, lavval_preprocessed, newagefsg_preprocessed], ignore_index=True)
# items_df = preprocessing(jamstones)

# %%
type(items_df['line_items'][200][0]['quantity'])
# Out:
# int

# %%
items_df
# Out:
#                   id                                         line_items
# 0      4093536043104  [{'id': 10557966286944, 'admin_graphql_api_id'...
# 1      4093506060384  [{'id': 10557885513824, 'admin_graphql_api_id'...
# 2      4093373120608  [{'id': 10557541810272, 'admin_graphql_api_id'...
# 3      4093166813280  [{'id': 10557052059744, 'admin_graphql_api_id'...
# 4      4092837363808  [{'id': 10556246884448, 'admin_graphql_api_id'...
# ...              ...                                                ...
# 13934  2674319327393  [{'id': 5785053888673, 'admin_graphql_api_id':...
# 13935  2673968054433  [{'id': 5784513413281, 'admin_graphql_api_id':...
# 13936  2673190043809  [{'id': 5783188865185, 'admin_graphql_api_id':...
# 13937  2655117574305  [{'id': 5752646762657, 'admin_graphql_api_id':...
# 13938  2654976868513  [{'id': 5752391467169, 'admin_graphql_api_id':...
#
# [13939 rows x 2 columns]

# %%
# items_df['line_items'][223]

# %%
test = "Agate Amazonite Amber Amethyst Ametrine Ammonite Angelite Apache Tear (Obsidian) Apatite Aquamarine Aragonite Auralite 23 Aventurine Azeztulite Azurite Beryl Black Rutilated Quartz Black Spinel Black Tourmaline Bloodstone Blue Lace Agate Boji Stone Bronzite Calcite Carborundum Carnelian Celestite Chalcedony Charoite Chiastolite Chrysoberyl Chrysocolla Chrysoprase Citrine Clear Quartz Dalmatian Jasper Danburite Dendritic Agate Diamond Diopside Emerald Enhydro Quartz Fire Agate Fire Opal Fluorite Fossil Coral Jasper Freshwater Pearl Fuchsite Garnet Gold Rutilated Quartz Gypsum Hematite Herkimer Diamond Hessonite Howlite Hypersthene Imperial Topaz Indicolite Iolite Iron Nickel Meteorite Iron Pyrite Jade Jasper Jet K2 Kunzite Kyanite Labradorite Landscape Jasper Lapis Lazuli Larimar Lemurian Seed Lepidolite Libyan Gold Tektite Malachite Mangano Calcite Moldavite Mookaite Jasper Moonstone Morganite Moss Agate Nebula Stone Obsidian Onyx Opal Peridot Petrified Wood Phantom Quartz Pietersite Prehnite Red Jasper Red Rutilated Quartz Rhodochrosite Rhodonite Rose Quartz Ruby Sapphire Selenite Seraphinite Serpentine Shungite Smoky Quartz Snowflake Obsidian Sodalite Spinel Spirit Quartz Staurolite Sugilite Sunstone Tanzanite Tektite Tibetan Quartz Tiger's Eye Topaz Tourmaline Turquoise Unakite Watermelon Tourmaline Zebra Jasper Zoisite"
test_list = test.split()
test_list
# Out:
# ['Agate',
#  'Amazonite',
#  'Amber',
#  'Amethyst',
#  'Ametrine',
#  'Ammonite',
#  'Angelite',
#  'Apache',
#  'Tear',
#  '(Obsidian)',
#  'Apatite',
#  'Aquamarine',
#  'Aragonite',
#  'Auralite',
#  '23',
#  'Aventurine',
#  'Azeztulite',
#  'Azurite',
#  'Beryl',
#  'Black',
#  'Rutilated',
#  'Quartz',
#  'Black',
#  'Spinel',
#  'Black',
#  'Tourmaline',
#  'Bloodstone',
#  'Blue',
#  'Lace',
#  'Agate',
#  'Boji',
#  'Stone',
#  'Bronzite',
#  'Calcite',
#  'Carborundum',
#  'Carnelian',
#  'Celestite',
#  'Chalcedony',
#  'Charoite',
#  'Chiastolite',
#  'Chrysoberyl',
#  'Chrysocolla',
#  'Chrysoprase',
#  'Citrine',
#  'Clear',
#  'Quartz',
#  'Dalmatian',
#  'Jasper',
#  'Danburite',
#  'Dendritic',
#  'Agate',
#  'Diamond',
#  'Diopside',
#  'Emerald',
#  'Enhydro',
#  'Quartz',
#  'Fire',
#  'Agate',
#  'Fire',
#  'Opal',
#  'Fluorite',
#  'Fossil',
#  'Coral',
#  'Jasper',
#  'Freshwater',
#  'Pearl',
#  'Fuchsite',
#  'Garnet',
#  'Gold',
#  'Rutilated',
#  'Quartz',
#  'Gypsum',
#  'Hematite',
#  'Herkimer',
#  'Diamond',
#  'Hessonite',
#  'Howlite',
#  'Hypersthene',
#  'Imperial',
#  'Topaz',
#  'Indicolite',
#  'Iolite',
#  'Iron',
#  'Nickel',
#  'Meteorite',
#  'Iron',
#  'Pyrite',
#  'Jade',
#  'Jasper',
#  'Jet',
#  'K2',
#  'Kunzite',
#  'Kyanite',
#  'Labradorite',
#  'Landscape',
#  'Jasper',
#  'Lapis',
#  'Lazuli',
#  'Larimar',
#  'Lemurian',
#  'Seed',
#  'Lepidolite',
#  'Libyan',
#  'Gold',
#  'Tektite',
#  'Malachite',
#  'Mangano',
#  'Calcite',
#  'Moldavite',
#  'Mookaite',
#  'Jasper',
#  'Moonstone',
#  'Morganite',
#  'Moss',
#  'Agate',
#  'Nebula',
#  'Stone',
#  'Obsidian',
#  'Onyx',
#  'Opal',
#  'Peridot',
#  'Petrified',
#  'Wood',
#  'Phantom',
#  'Quartz',
#  'Pietersite',
#  'Prehnite',
#  'Red',
#  'Jasper',
#  'Red',
#  'Rutilated',
#  'Quartz',
#  'Rhodochrosite',
#  'Rhodonite',
#  'Rose',
#  'Quartz',
#  'Ruby',
#  'Sapphire',
#  'Selenite',
#  'Seraphinite',
#  'Serpentine',
#  'Shungite',
#  'Smoky',
#  'Quartz',
#  'Snowflake',
#  'Obsidian',
#  'Sodalite',
#  'Spinel',
#  'Spirit',
#  'Quartz',
#  'Staurolite',
#  'Sugilite',
#  'Sunstone',
#  'Tanzanite',
#  'Tektite',
#  'Tibetan',
#  'Quartz',
#  "Tiger's",
#  'Eye',
#  'Topaz',
#  'Tourmaline',
#  'Turquoise',
#  'Unakite',
#  'Watermelon',
#  'Tourmaline',
#  'Zebra',
#  'Jasper',
#  'Zoisite']

# %%
crystals = ['Agate',
 'Amazonite',
 'Amber',
 'Amethyst',
 'Ametrine',
 'Ammonite',
 'Angelite',
 'Apache Tear',
 'Apatite',
 'Aquamarine',
 'Aragonite',
 'Auralite 23',
 'Aventurine',
 'Azeztulite',
 'Azurite',
 'Beryl',
 'Black Rutilated Quartz',
 'Black Spinel',
 'Black Tourmaline',
 'Bloodstone',
 'Blue Lace Agate',
 'Boji Stone',
 'Bronzite',
 'Calcite',
 'Carborundum',
 'Carnelian',
 'Celestite',
 'Chalcedony',
 'Charoite',
 'Chiastolite',
 'Chrysoberyl',
 'Chrysocolla',
 'Chrysoprase',
 'Citrine',
 'Clear Quartz',
 'Dalmatian Jasper',
 'Danburite',
 'Dendritic',
 'Agate',
 'Diamond',
 'Diopside',
 'Emerald',
 'Enhydro Quartz',
 'Fire Agate',
 'Fire Opal',
 'Fluorite',
 'Fossil Coral Jasper',
 'Freshwater Pearl',
 'Fuchsite',
 'Garnet',
 'Gold Rutilated Quartz',
 'Gypsum',
 'Hematite',
 'Herkimer Diamond',
 'Hessonite',
 'Howlite',
 'Hypersthene',
 'Imperial Topaz',
 'Indicolite',
 'Iolite',
 'Iron Nickel Meteorite',
 'Iron Pyrite',
 'Jade',
 'Jasper',
 'Jet',
 'K2',
 'Kunzite',
 'Kyanite',
 'Labradorite',
 'Landscape Jasper',
 'Lapis Lazuli',
 'Larimar',
 'Lemurian Seed',
 'Lepidolite',
 'Libyan Gold Tektite',
 'Malachite',
 'Mangano Calcite',
 'Moldavite',
 'Mookaite Jasper',
 'Moonstone',
 'Morganite',
 'Moss Agate',
 'Nebula Stone',
 'Obsidian',
 'Onyx',
 'Opal',
 'Peridot',
 'Petrified Wood',
 'Phantom Quartz',
 'Pietersite',
 'Prehnite',
 'Red Jasper',
 'Red Rutilated Quartz',
 'Rhodochrosite',
 'Rhodonite',
 'Rose Quartz',
 'Ruby',
 'Sapphire',
 'Selenite',
 'Seraphinite',
 'Serpentine',
 'Shungite',
 'Smoky Quartz',
 'Snowflake Obsidian',
 'Sodalite',
 'Spinel',
 'Spirit Quartz',
 'Staurolite',
 'Sugilite',
 'Sunstone',
 'Tanzanite',
 'Tektite',
 'Tibetan Quartz',
 "Tiger's Eye",
 'Topaz',
 'Tourmaline',
 'Turquoise',
 'Unakite',
 'Watermelon Tourmaline',
 'Zebra Jasper',
 'Zoisite']

# %%
len(crystals)
# Out:
# 121

# %%
crystals = [crystal.lower() for crystal in crystals]
crystals
# Out:
# ['agate',
#  'amazonite',
#  'amber',
#  'amethyst',
#  'ametrine',
#  'ammonite',
#  'angelite',
#  'apache tear',
#  'apatite',
#  'aquamarine',
#  'aragonite',
#  'auralite 23',
#  'aventurine',
#  'azeztulite',
#  'azurite',
#  'beryl',
#  'black rutilated quartz',
#  'black spinel',
#  'black tourmaline',
#  'bloodstone',
#  'blue lace agate',
#  'boji stone',
#  'bronzite',
#  'calcite',
#  'carborundum',
#  'carnelian',
#  'celestite',
#  'chalcedony',
#  'charoite',
#  'chiastolite',
#  'chrysoberyl',
#  'chrysocolla',
#  'chrysoprase',
#  'citrine',
#  'clear quartz',
#  'dalmatian jasper',
#  'danburite',
#  'dendritic',
#  'agate',
#  'diamond',
#  'diopside',
#  'emerald',
#  'enhydro quartz',
#  'fire agate',
#  'fire opal',
#  'fluorite',
#  'fossil coral jasper',
#  'freshwater pearl',
#  'fuchsite',
#  'garnet',
#  'gold rutilated quartz',
#  'gypsum',
#  'hematite',
#  'herkimer diamond',
#  'hessonite',
#  'howlite',
#  'hypersthene',
#  'imperial topaz',
#  'indicolite',
#  'iolite',
#  'iron nickel meteorite',
#  'iron pyrite',
#  'jade',
#  'jasper',
#  'jet',
#  'k2',
#  'kunzite',
#  'kyanite',
#  'labradorite',
#  'landscape jasper',
#  'lapis lazuli',
#  'larimar',
#  'lemurian seed',
#  'lepidolite',
#  'libyan gold tektite',
#  'malachite',
#  'mangano calcite',
#  'moldavite',
#  'mookaite jasper',
#  'moonstone',
#  'morganite',
#  'moss agate',
#  'nebula stone',
#  'obsidian',
#  'onyx',
#  'opal',
#  'peridot',
#  'petrified wood',
#  'phantom quartz',
#  'pietersite',
#  'prehnite',
#  'red jasper',
#  'red rutilated quartz',
#  'rhodochrosite',
#  'rhodonite',
#  'rose quartz',
#  'ruby',
#  'sapphire',
#  'selenite',
#  'seraphinite',
#  'serpentine',
#  'shungite',
#  'smoky quartz',
#  'snowflake obsidian',
#  'sodalite',
#  'spinel',
#  'spirit quartz',
#  'staurolite',
#  'sugilite',
#  'sunstone',
#  'tanzanite',
#  'tektite',
#  'tibetan quartz',
#  "tiger's eye",
#  'topaz',
#  'tourmaline',
#  'turquoise',
#  'unakite',
#  'watermelon tourmaline',
#  'zebra jasper',
#  'zoisite']

# %%
#name, quantity
#transaction set per row trans_list = [name, name2, name2 ...]
def remove_suffix(input_string, suffix):
    if suffix and input_string.endswith(suffix):
        return input_string[:-len(suffix)]
    return input_string

categories = ['bracelet', 'necklace','pendant', 'earrings', 'ring', 'lamp', 'bottle', 'tower', 'pendulum', 'bead', 'tumble', 'display', 'pouches', 'kits', 'bag charm', 'charm', 'bag', 'kit', 'tree', 'pouch', 'solitaire', 'pointer', 'hedgehog', 'chip']

crystals = ['agate',
 'amazonite',
 'amber',
 'amethyst',
 'ametrine',
 'ammonite',
 'angelite',
 'apache tear',
 'apatite',
 'aquamarine',
 'aragonite',
 'auralite 23',
 'aventurine',
 'azeztulite',
 'azurite',
 'beryl',
 'black rutilated quartz',
 'black spinel',
 'black tourmaline',
 'bloodstone',
 'blue lace agate',
 'boji stone',
 'bronzite',
 'calcite',
 'carborundum',
 'carnelian',
 'celestite',
 'chalcedony',
 'charoite',
 'chiastolite',
 'chrysoberyl',
 'chrysocolla',
 'chrysoprase',
 'citrine',
 'clear quartz',
 'dalmatian jasper',
 'danburite',
 'dendritic',
 'agate',
 'diamond',
 'diopside',
 'emerald',
 'enhydro quartz',
 'fire agate',
 'fire opal',
 'fluorite',
 'fossil coral jasper',
 'freshwater pearl',
 'fuchsite',
 'garnet',
 'gold rutilated quartz',
 'gypsum',
 'hematite',
 'herkimer diamond',
 'hessonite',
 'howlite',
 'hypersthene',
 'imperial topaz',
 'indicolite',
 'iolite',
 'iron nickel meteorite',
 'iron pyrite',
 'jade',
 'jasper',
 'jet',
 'k2',
 'kunzite',
 'kyanite',
 'labradorite',
 'landscape jasper',
 'lapis lazuli',
 'larimar',
 'lemurian seed',
 'lepidolite',
 'libyan gold tektite',
 'malachite',
 'mangano calcite',
 'moldavite',
 'mookaite jasper',
 'moonstone',
 'morganite',
 'moss agate',
 'nebula stone',
 'obsidian',
 'onyx',
 'opal',
 'peridot',
 'petrified wood',
 'phantom quartz',
 'pietersite',
 'prehnite',
 'red jasper',
 'red rutilated quartz',
 'rhodochrosite',
 'rhodonite',
 'rose quartz',
 'ruby',
 'sapphire',
 'selenite',
 'seraphinite',
 'serpentine',
 'shungite',
 'smoky quartz',
 'snowflake obsidian',
 'sodalite',
 'spinel',
 'spirit quartz',
 'staurolite',
 'sugilite',
 'sunstone',
 'tanzanite',
 'tektite',
 'tibetan quartz',
 "tiger's eye",
 'topaz',
 'tourmaline',
 'turquoise',
 'unakite',
 'watermelon tourmaline',
 'zebra jasper',
 'zoisite']

def get_category(name):
    for category in categories:
        if category in name.lower():
            return category
    else:
        return 'others'
    
def get_crystal(name):
    for crystal in crystals:
        if crystal in name.lower():
            return crystal
    else:
        return 'others'
    
def remove_live_sale(sublist):
    remove_substring = 'Live Sale $1 Listing'
    new_sublist = []
    for item in sublist:
        if remove_substring not in item:
            new_sublist.append(item)
            
    return new_sublist
    
def items_per_transaction(row):
    num_items = len(row)
    trans_list = []
    categories_list = []
    crystals_list = []
    
    #items
    for i in range(num_items):
        temp_quantity = row[i]['quantity']
        for j in range(temp_quantity):
            substring = '(Not found on Shopify)'
            name = row[i]['name']
            if substring in name:
                name = remove_suffix(name, substring)
            trans_list.append(name)
    
    trans_list = remove_live_sale(trans_list)
            
    #categories and crystals
    for item in trans_list:
        category = get_category(item)
        crystal = get_crystal(item)
        categories_list.append(category)
        crystals_list.append(crystal)
             
    return trans_list, categories_list, crystals_list


def get_unique_items(some_list):
    flat_list = [item for sublist in some_list for item in sublist]
    unique_list = []
    for item in flat_list:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list
    
def transaction_items(df):
    df_copy = preprocessing(df)
    line_items_list = df_copy.line_items.tolist()
    items_per_transaction_list = [items_per_transaction(row) for row in line_items_list]
    df_copy['items_per_transaction'] = items_per_transaction_list   
    
    unique_items = get_unique_items(items_per_transaction_list)
            
    return unique_items

def remove_empty_transactions(row):
    for item in row:
        if item == []:
            row.remove(item)
            
    return row

# unique_items = transaction_items(jamstones)

# %%
line_items_list = items_df.line_items.tolist()
items_per_transaction_list = [items_per_transaction(row)[0] for row in line_items_list]
categories_per_transaction_list = [items_per_transaction(row)[1] for row in line_items_list]
crystals_per_transaction_list = [items_per_transaction(row)[2] for row in line_items_list]
items_per_transaction_list = remove_empty_transactions(items_per_transaction_list)
categories_per_transaction_list = remove_empty_transactions(categories_per_transaction_list)
crystals_per_transaction_list = remove_empty_transactions(crystals_per_transaction_list)
d = {'items_per_transaction': items_per_transaction_list, 'categories_per_transaction': categories_per_transaction_list, 'crystals_per_transaction': crystals_per_transaction_list}
temp_df = pd.DataFrame(data=d)
temp_df
# Out:
#                                    items_per_transaction  \
# 0      [[READY PRODUCT] Crystal Bag Charm Jamstones ,...
# 1      [[READY PRODUCT] Crystal Bag Charm Jamstones ,...
# 2      [[READY PRODUCT] Crystal Bag Charm Jamstones ,...
# 3      [[Jamstones x Lavval] Sugar & Spice Necklace (...
# 4      [Career (Calmness, Healing, Wisdom, Wealth), B...
# ...                                                  ...
# 13268  [Howlite 6mm Bracelet, Black Tourmaline 6mm Br...
# 13269     [Aventurine 8mm Bracelet, Ruby Zosite Pointer]
# 13270  [Hematite Tumble, Clear Quartz Tumble, Mini Se...
# 13271                                           [TEST 1]
# 13272                           [Fluorite Kitty Pendant]
#
#                               categories_per_transaction  \
# 0                                 [bag charm, bag charm]
# 1                                 [bag charm, bag charm]
# 2                                 [bag charm, bag charm]
# 3                         [necklace, necklace, bracelet]
# 4                           [others, necklace, necklace]
# ...                                                  ...
# 13268  [bracelet, bracelet, bracelet, bracelet, brace...
# 13269                                [bracelet, pointer]
# 13270              [tumble, tumble, tower, pouch, pouch]
# 13271                                           [others]
# 13272                                          [pendant]
#
#                                 crystals_per_transaction
# 0                                       [others, others]
# 1                                       [others, others]
# 2                                       [others, others]
# 3                               [others, others, others]
# 4                               [others, others, others]
# ...                                                  ...
# 13268  [howlite, black tourmaline, bronzite, rose qua...
# 13269                                 [aventurine, ruby]
# 13270  [hematite, clear quartz, selenite, others, oth...
# 13271                                           [others]
# 13272                                         [fluorite]
#
# [13273 rows x 3 columns]

# %%
crystals_per_transaction_list
# Out:
# [['others', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'selenite'],
#  ['others', 'angelite'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'selenite', 'selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['selenite', 'others'],
#  ['rose quartz'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['rose quartz'],
#  ['others'],
#  ['others'],
#  ['angelite'],
#  ['others'],
#  ['selenite'],
#  ['selenite', 'selenite'],
#  ['agate'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['agate'],
#  ['selenite', 'others'],
#  ['others', 'agate'],
#  ['lepidolite',
#   'howlite',
#   'agate',
#   'selenite',
#   'rhodonite',
#   'others',
#   'citrine',
#   'amazonite',
#   'aquamarine'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['black tourmaline',
#   'black tourmaline',
#   'black tourmaline',
#   'black tourmaline',
#   'black tourmaline',
#   'black tourmaline'],
#  ['rose quartz', 'others'],
#  ['selenite', 'amethyst', 'black tourmaline'],
#  ['others', 'others'],
#  ['others', 'amethyst'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others', 'jade'],
#  ['others'],
#  ['others'],
#  ['aquamarine', 'amethyst'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'jade'],
#  ['others'],
#  ['others'],
#  ['bronzite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['selenite', 'selenite', 'selenite'],
#  ['agate', 'citrine'],
#  ['selenite', 'selenite'],
#  ['others'],
#  ['others', 'others', 'selenite', 'others'],
#  ['citrine', 'others', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others', 'rose quartz'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'selenite', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['jade', 'angelite', 'others'],
#  ['others', 'others', 'labradorite'],
#  ['others', 'others', 'others'],
#  ['agate', 'agate', 'others'],
#  ['others'],
#  ['others'],
#  ['agate'],
#  ['phantom quartz'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['jade', 'others', 'selenite'],
#  ['others'],
#  ['others', 'others', 'agate'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['selenite'],
#  ['others'],
#  ['tourmaline', 'tourmaline'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'freshwater pearl'],
#  ['tourmaline'],
#  ['tourmaline'],
#  ['others'],
#  ['others', 'others', 'tourmaline'],
#  ['others', 'others', 'others'],
#  ['amazonite', 'amethyst'],
#  ['others', 'obsidian'],
#  ['others'],
#  ['others', 'rose quartz', 'amethyst'],
#  ['selenite'],
#  ['others'],
#  ['sunstone'],
#  ['others'],
#  ['tourmaline'],
#  ['others'],
#  ['phantom quartz', 'labradorite', 'agate', 'others', 'others', 'others'],
#  ['bloodstone', 'others'],
#  ['selenite'],
#  ['agate'],
#  ['others'],
#  ['others'],
#  ['rose quartz', 'others', 'others'],
#  ['agate'],
#  ['others'],
#  ['others'],
#  ['kyanite',
#   'kyanite',
#   'kyanite',
#   'turquoise',
#   'turquoise',
#   'turquoise',
#   'phantom quartz',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'kyanite',
#   'kyanite'],
#  ['others'],
#  ['bloodstone'],
#  ['moonstone'],
#  ['others', 'others'],
#  ['angelite'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['lepidolite'],
#  ['others', 'others', 'others', 'others', 'others', 'others', 'others'],
#  ['rose quartz'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['angelite', 'selenite'],
#  ['carnelian'],
#  ['clear quartz'],
#  ['others'],
#  ['others'],
#  ['agate'],
#  ['others'],
#  ['rose quartz'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['angelite', 'angelite', 'rose quartz'],
#  ['others'],
#  ['jade', 'others'],
#  ['selenite'],
#  ['others'],
#  ['moonstone', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['jade'],
#  ['others', 'others'],
#  ['others'],
#  ['citrine'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['citrine'],
#  ['others'],
#  ['others'],
#  ['agate', 'others'],
#  ['others'],
#  ['others', 'citrine'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['labradorite', 'others', 'others', 'others', 'others', 'others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['rose quartz', 'others', 'agate', 'agate'],
#  ['lepidolite'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['ametrine'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['jade', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['ametrine'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'rose quartz', 'others'],
#  ['others', 'rose quartz', 'others', 'others', 'others', 'others', 'others'],
#  ['others', 'others', 'selenite'],
#  ['others'],
#  ['others', 'others'],
#  ['jade'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['angelite'],
#  ['others'],
#  ['others', 'freshwater pearl', 'freshwater pearl'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['moonstone'],
#  ['jade', 'others'],
#  ['others'],
#  ['agate', 'agate'],
#  ['others'],
#  ['others'],
#  ['others', 'amethyst', 'amethyst', 'amethyst'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['selenite', 'others', 'others'],
#  ['amethyst'],
#  ['selenite'],
#  ['others'],
#  ['others', 'others'],
#  ['jade'],
#  ['others'],
#  ['bloodstone', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'selenite', 'clear quartz'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['moonstone'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['selenite', 'selenite', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'kyanite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['amazonite'],
#  ['others'],
#  ['others'],
#  ['others', 'kyanite'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['ametrine', 'others'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['rose quartz', 'others', 'others'],
#  ['others', 'selenite'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['others', 'others'],
#  ['others'],
#  ['lepidolite',
#   'sodalite',
#   'howlite',
#   'others',
#   'rhodonite',
#   'amethyst',
#   'amazonite',
#   'black tourmaline',
#   'bronzite',
#   'fluorite'],
#  ['others'],
#  ['others', 'others'],
#  ['selenite', 'selenite', 'others'],
#  ['others', 'others'],
#  ['others', 'selenite'],
#  ['others', 'others', 'others'],
#  ['others', 'amethyst'],
#  ['others'],
#  ['larimar'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['larimar'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['charoite', 'peridot', 'apatite'],
#  ['agate'],
#  ['selenite', 'selenite'],
#  ['selenite'],
#  ['selenite'],
#  ['jade'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'selenite', 'others', 'others'],
#  ['others'],
#  ['jasper', 'jasper', 'jasper'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['jade', 'agate'],
#  ['others'],
#  ['others', 'amethyst'],
#  ['selenite', 'others'],
#  ['rose quartz', 'citrine'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others', 'others'],
#  ['aquamarine'],
#  ['others', 'peridot'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['selenite', 'selenite'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['amethyst'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'agate'],
#  ['others', 'others', 'others', 'amethyst', 'others', 'others', 'others'],
#  ['others', 'amethyst', 'amethyst'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['selenite', 'selenite'],
#  ['agate'],
#  ['selenite', 'jade', 'others', 'others', 'others', 'citrine'],
#  ['selenite', 'selenite'],
#  ['others', 'others'],
#  ['others'],
#  ['citrine', 'moonstone', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'selenite', 'others'],
#  ['jade'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['aquamarine'],
#  ['others', 'phantom quartz'],
#  ['others'],
#  ['selenite', 'others', 'others', 'others', 'others'],
#  ['selenite'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'angelite'],
#  ['selenite', 'others', 'fluorite', 'selenite'],
#  ['others', 'angelite'],
#  ['others', 'others', 'others'],
#  ['jade'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['selenite'],
#  ['selenite'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'others', 'selenite'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['agate',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['shungite'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['selenite', 'selenite', 'selenite'],
#  ['others'],
#  ['others'],
#  ['larimar', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['amethyst', 'selenite', 'others', 'others', 'others'],
#  ['selenite', 'selenite', 'selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'selenite'],
#  ['others'],
#  ['others', 'agate'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others', 'bloodstone'],
#  ['others'],
#  ['selenite'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['agate'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'agate'],
#  ['rose quartz', 'rose quartz'],
#  ['others'],
#  ['agate'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['agate'],
#  ['others'],
#  ['others'],
#  ['freshwater pearl', 'freshwater pearl', 'freshwater pearl'],
#  ['jade'],
#  ['others'],
#  ['selenite', 'others'],
#  ['others', 'clear quartz', 'clear quartz', 'others', 'moonstone', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['agate'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['selenite', 'selenite', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['rose quartz', 'rose quartz'],
#  ['agate', 'others'],
#  ['selenite'],
#  ['others'],
#  ['others', 'amethyst', 'others', 'fluorite', 'others'],
#  ['agate'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['selenite'],
#  ['selenite'],
#  ['others'],
#  ['tourmaline'],
#  ['others', 'selenite'],
#  ['others',
#   'black tourmaline',
#   'black tourmaline',
#   'black tourmaline',
#   'bronzite'],
#  ['selenite'],
#  ['others', 'others'],
#  ['others', 'amethyst', 'peridot', 'selenite'],
#  ['others'],
#  ['others', 'amethyst'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['selenite'],
#  ['selenite', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['agate'],
#  ['others'],
#  ['selenite'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others', 'others', 'others'],
#  ['selenite'],
#  ['selenite'],
#  ['others'],
#  ['others'],
#  ['jade', 'selenite'],
#  ['others',
#   'selenite',
#   'citrine',
#   'amethyst',
#   'amethyst',
#   'howlite',
#   'howlite',
#   'howlite',
#   'howlite',
#   'howlite',
#   'howlite',
#   'howlite',
#   'howlite'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others', 'amethyst', 'agate', 'angelite'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['selenite', 'others', 'selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'agate'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'rose quartz', 'rose quartz'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'tourmaline', 'others'],
#  ['agate', 'others', 'others', 'jasper'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['agate'],
#  ['others'],
#  ['others', 'black tourmaline', 'aquamarine', 'selenite'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'apatite', 'obsidian'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['moonstone', 'moonstone'],
#  ['others'],
#  ['others'],
#  ['others', 'amethyst', 'charoite', 'apatite'],
#  ['others', 'others'],
#  ['rose quartz'],
#  ['others', 'others'],
#  ['larimar'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'jade',
#   'amethyst'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['fluorite', 'others'],
#  ['others', 'others'],
#  ['others', 'larimar', 'others', 'larimar', 'others'],
#  ['others'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['others'],
#  ['smoky quartz'],
#  ['others'],
#  ['others', 'agate'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['citrine'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'jade'],
#  ['jade', 'others'],
#  ['others', 'others'],
#  ['others', 'kunzite', 'rose quartz', 'jade'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'jade', 'jade', 'others', 'others'],
#  ['agate'],
#  ['others'],
#  ['others'],
#  ['selenite', 'selenite'],
#  ['others'],
#  ['others'],
#  ['selenite'],
#  ['lepidolite', 'rhodonite'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['shungite', 'selenite', 'others'],
#  ['others', 'rhodonite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['agate', 'angelite'],
#  ['others'],
#  ['others'],
#  ['rose quartz'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['moonstone'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['selenite', 'selenite'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'agate'],
#  ['others', 'fluorite'],
#  ['larimar', 'others'],
#  ['others'],
#  ['tourmaline'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['tourmaline'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['amethyst'],
#  ['amethyst'],
#  ['amethyst', 'rose quartz'],
#  ['amethyst', 'amethyst', 'amethyst'],
#  ['amethyst', 'amethyst'],
#  ['amethyst', 'amethyst'],
#  ['amethyst'],
#  ['others'],
#  ['amethyst'],
#  ['amethyst'],
#  ['amethyst', 'amethyst', 'amethyst', 'amethyst'],
#  ['amethyst', 'amethyst', 'others'],
#  ['amethyst', 'amethyst'],
#  ['amethyst'],
#  ['others', 'others', 'amethyst', 'others'],
#  ['selenite'],
#  ['others'],
#  ['others'],
#  ['amethyst', 'amethyst'],
#  ['amethyst'],
#  ['others', 'amethyst', 'larimar'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'selenite'],
#  ['others', 'others', 'selenite', 'lapis lazuli'],
#  ['others', 'pietersite'],
#  ['angelite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'agate', 'agate'],
#  ['others'],
#  ['selenite'],
#  ['others'],
#  ['selenite'],
#  ['charoite'],
#  ['others', 'selenite'],
#  ['others', 'jade'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['jade'],
#  ['others'],
#  ['lapis lazuli', 'lapis lazuli'],
#  ['others', 'selenite'],
#  ['others'],
#  ['tanzanite', 'others'],
#  ['moonstone', 'labradorite'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'citrine'],
#  ['phantom quartz'],
#  ['larimar'],
#  ['others'],
#  ['others'],
#  ['jade', 'agate'],
#  ['pietersite', 'pietersite'],
#  ['others'],
#  ['fluorite', 'fluorite'],
#  ['others'],
#  ['others'],
#  ['others', 'selenite', 'others'],
#  ['others'],
#  ['rose quartz', 'amethyst'],
#  ['agate'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others', 'carnelian', 'rose quartz', 'others', 'others'],
#  ['selenite'],
#  ['others', 'others'],
#  ['others', 'selenite', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['amethyst'],
#  ['others', 'jade'],
#  ['selenite', 'selenite'],
#  ['others', 'others'],
#  ['agate'],
#  ['lepidolite'],
#  ['others'],
#  ['pietersite'],
#  ['others', 'others'],
#  ['others'],
#  ['agate',
#   'agate',
#   'agate',
#   'agate',
#   'agate',
#   'agate',
#   'agate',
#   'agate',
#   'agate',
#   'agate'],
#  ['lapis lazuli'],
#  ['others', 'others'],
#  ['agate'],
#  ['others', 'others', 'others'],
#  ['others', 'angelite', 'others'],
#  ['others'],
#  ['lapis lazuli'],
#  ['amethyst'],
#  ['rose quartz', 'rose quartz'],
#  ['agate'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['selenite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['agate'],
#  ['others'],
#  ['amethyst', 'apatite'],
#  ['selenite'],
#  ['others', 'rose quartz', 'amethyst', 'amethyst'],
#  ['others'],
#  ['selenite'],
#  ['rose quartz'],
#  ['others', 'bloodstone', 'charoite'],
#  ['jade'],
#  ['selenite', 'angelite'],
#  ['others', 'amethyst'],
#  ['others', 'amethyst'],
#  ['lepidolite'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ...]

# %%
# copy_df.to_csv('copy_df.csv')

# %%
items_per_transaction_list
# Out:
# [['[READY PRODUCT] Crystal Bag Charm Jamstones ',
#   '[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['[READY PRODUCT] Crystal Bag Charm Jamst

#  ['[Jamstones x Lavval] Solitaire Crystal Necklace [Choose from 20+ centerpieces] ',
#   '[Jamstones x Lavval] Sophie Crystal Bracelet ',
#   '[Jamstones x Lavval] Sophie Crystal Bracelet '],
#  ['Blaire (Protection, Creativity and Calmness)',
#   'Minty( Love, Weight-Loss and Wisdom) '],
#  ['[Jamstones x Lavval] Dena Crystal Bracelet [ Calmness, Protection and Growth] 8.8 '],
#  ['Delivery for JS8152'],
#  ['[Jamstones x Lavval] Classic Jade Earrings ',
#   '[Jamstones x Lavval] Customise your own Earrings! [Shopee Live] ',
#   '[Jamstones x Lavval ] Selenite Tray '],
#  ['Auburn *Geometric Crystal contains surface marks/potholes* (Anti- Evil eye and Positivity)'],
#  ['[Jamstones x Lavval] Crystal Magical Unicorn [Love,Wealth] ',
#   '[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) ',
#   '[Jamstones x Lavval] Rainbow Alashan Agate Crystal Necklace '],
#  ['[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] ',
#   'Saber ( Anti-Evil Eye, Protection and Wealth) '],
#  ['[Jamstones x Lavval] Estella Crystal Bracelet [Love,Wisdom] ',
#   '[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] '],
#  ['Selenite Crystal Fumao [Jamstones x Lavval] '],
#  ['[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['[Jamstones x Lavval] Silver Tri-Tourmaline Garden Ring ',
#   '[Jamstones x Lavval] Silver Tri-Tourmaline Garden Ring '],
#  ['[Jamstones x Lavval] Estella Crystal Bracelet [Love,Wisdom] '],
#  ['[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['[Jamstones x Lavval] Healing Crystal Tree '],
#  ['[Jamstones x Lavval] Kandy (Love, Calmness and Wisdom) ',
#   '[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] ',
#   'Saber ( Anti-Evil Eye, Protection and Wealth) '],
#  ['[Jamstones x Lavval] Sabrina (Love, Positivity, Wisdom and Healing) '],
#  ['[Jamstones x Lavval] Emery Crystal Bracelet [Luck,Wisdom] '],
#  ['[Jamstones x Lavval] Wisdom  - Shopee Exclusive Crystal Bracelet [Wisdom,Wealth] ',
#   '[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] ',
#   '[Jamstones x Lavval] Dainty Freshwater Pearl Stacker Bracelet '],
#  ['[Jamstones x Lavval] Silver Tri-Tourmaline Garden Ring '],
#  ['[Jamstones x Lavval] Silver Tri-Tourmaline Garden Ring '],
#  ['Maia (Confidence, Career, Happiness and Peace)'],
#  ['[Jamstones x Lavval] Crystal Baby Bear [Love,Wealth] ',
#   '[Jamstones x Lavval] Crystal Baby Bear [Love,Wealth] ',
#   '[Jamstones x Lavval] Silver Tri-Tourmaline Garden Ring '],
#  ['[Jamstones x Lavval] Jewel in A Box RESTOCKED 4 Crystal Bracelet [Wisdom] ',
#   '[Jamstones x Lavval] Dena Crystal Bracelet [ Calmness, Protection and Growth] 8.8 ',
#   '[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] '],
#  ['unicorn amazonite', 'Healing Crystal Trees - Amethyst'],
#  ['Calmness shopee bracelet',
#   'Midnight Magic (Anti-Evil Eye and Protection) - 2. Obsidian Stacker Charm Bracelet'],
#  ['[Jamstones x Lavval] Estella Crystal Bracelet [Love,Wisdom] '],
#  ['Sugar & Spice Necklace (Love, Wealth and Weight-Loss)',
#   'Charm Stacker Crystal Bracelet - Rose Quartz (Love)',
#   'DAINTY Bracelets ( Cool ) - Chevron Amethyst / Heart / Rondell'],
#  ['Selenite Crystal Fumao [Jamstones x Lavval] '],
#  ['Maia (Confidence, Career, Happiness and Peace)'],
#  ['Premium Crystal Heart Stacker Series - Sunstone'],
#  ['JS IG LIVE'],
#  ['[Jamstones x Lavval] Silver Tri-Tourmaline Garden Ring '],
#  ['JS IG LIVE'],
#  ['[Jamstones x Lavval] Phantom Quartz Globe Pendant ',
#   'Mermaid Dream Crystal Earrings (Madeat6pm x Jam.Stones Special Collaboration ) - Labradorite',
#   'Mermaid Dream Crystal Earrings (Madeat6pm x Jam.Stones Special Collaboration ) - Blue Lace Agate',
#   '[JamStones x Lavval] Ombré Magical Unicorn Crystal Resin ',
#   '[JamStones x Lavval] Ombré Magical Unicorn Crystal Resin ',
#   '[JamStones x Lavval] Ombré Magical Unicorn Crystal Resin '],
#  ['[Jamstones x NewageFSG] Bloodstone Mini Pointer ',
#   '[Jamstones x NewageFSG SG LOCAL] Smoky Elestial Quartz '],
#  ['[Jamstones x Lavval ] Selenite Tray '],
#  ['[Jamstones x Lavval] Artsy Agate Keychain '],
#  ['[Jamstones x Lavval] Jolly Crystal Bracelet [Love,Healing,Wisdom,Wealth] '],
#  ['[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] '],
#  ['[Jamstones x NewageFSG SG LOCAL] Rose Quartz Crystal Bracelet 6mm ',
#   '[Jamstones x Lavval] Lucky Clover  Crystal Bracelet [Wisdom] ',
#   '[JamStones x Lavval] Ombré Magical Unicorn Crystal Resin '],
#  ['2.0 Rainbow Alashan Agate Crystal Necklace'],
#  ['[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['Shopee Live'],
#  ['kyanite bear (qty3)',
#   'kyanite bear (qty3)',
#   'kyanite bear (qty3)',
#   'Turquoise bear',
#   'Turquoise bear',
#   'Turquoise bear',
#   'Phantom Quartz Solitaire (Career and Healing)',
#   'custom bracelet',
#   'custom bracelet',
#   'earrings',
#   'earrings',
#   'earrings',
#   'earrings',
#   'gift box',
#   'gift box',
#   'gift box',
#   'gift box',
#   'gift box',
#   'gift box',
#   'gift box',
#   '1 kyanite 1 turoqise bear',
#   '1 kyanite bear and 1 turoqise'],
#  ['[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['[Jamstones x NewageFSG] Bloodstone Mini Pointer '],
#  ['Snowflake Blue Sheen Moonstone Crystal Bracelet '],
#  ['[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) ',
#   '[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['[Jamstones x Lavval] Green Angelite  - Shopee Exclusive Crystal Bracelet [Weight Loss] '],
#  ['[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet '],
#  ['Lepidolite Tumble (Healing and Positivity)'],
#  ['Happiness (Calmness, Healing, Luck, Wisdom)',
#   'Lucky Clover',
#   'Miranda ( Love, Self-Expression, Positivity and Female Wellness)',
#   'Celine (Luck, Fortune, Calmness and Protection)',
#   'Miranda ( Love, Self-Expression, Positivity and Female Wellness)',
#   'Lavender ( Focus, Creativity and anti-anxiety)',
#   'Karla ( Honesty, Calmness, Clarity & Healing)'],
#  ['Candice - Rose Quartz'],
#  ['Amore - Love (Madeat6pm x Jam.Stones Special Collaboration )'],
#  ['[Jamstones x Lavval] Workshop Vouchers '],
#  ['[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet '],
#  ['[Jamstones x Lavval] Green Angelite  - Shopee Exclusive Crystal Bracelet [Weight Loss] ',
#   '[Jamstones x Lavval ] Selenite Tray '],
#  ['[Jamstones x NewageFSG SG LOCAL] Carnelian Sphere '],
#  ['[Jamstones x NewageFSG SG LOCAL] Clear Quartz Crystal Tumble (Clarity and Healing) '],
#  ['[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['[READY PRODUCT] Crystal Bag Charm Jamstones '],
#  ['Sieber Agate Stars Cloud [NewageFSG x Jamstones] '],
#  ['[Jamstones x Lavval] Healing Crystal Tree '],
#  ['Geometric Stacker Bracelet - Rose Quartz'],
#  ['[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) '],
#  ['[Jamstones x Lavval] Peace [II] Crystal Bracelet [Healing,Wisdom] '],
#  ['[Jamstones x Lavval] Dahlia Crystal Bracelet [Protection, Positivity and Healing] '],
#  ['[Jamstones x Lavval] Wisdom  - Shopee Exclusive Crystal Bracelet [Wisdom,Wealth] '],
#  ['Amore - Love (Madeat6pm x Jam.Stones Special Collaboration )'],
#  ['Austria Crystal Bracelet [Jamstones x Lavval] '],
#  ['Amore - Love (Madeat6pm x Jam.Stones Special Collaboration )'],
#  ['[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) ',
#   '[Jamstones x Lavval] Calmness  - Shopee Exclusive Crystal Bracelet [Calmness,Wisdom] '],
#  ['[Jamstones x NewageFSG SG LOCAL] Sea Salt '],
#  ['Alashan Rainbow Crystal Bracelet'],
#  ['[Jamstones x Lavval] Wisdom  - Shopee Exclusive Crystal Bracelet [Wisdom,Wealth
],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['White Sheen Moonstone Solitaire (Peace and Happiness) - Rose Gold'],
#  ['[Jamstones x Lavval] Classic Jade Earrings ',
#   '[Jamstones x Lavval] Crystal Stacker Bracelet - Pastel Series '],
#  ['IG LIVE'],
#  ['Sieber Agate Stars Cloud [NewageFSG x Jamstones] ',
#   '[Jamstones x Lavval] Plum White Agate Crystal Unicorn, Bear, Snowflake, Butterfly and Angel Wing '],
#  ['js IG LIVE'],
#  ['js ig live'],
#  ['[Jamstones x Lavval] Solitaire Crystal Necklace [Choose from 20+ centerpieces] ',
#   '[Jamstones x Lavval] Amethyst Chips Bottle ',
#   '[Jamstones x Lavval] Amethyst Chips Bottle ',
#   '[Jamstones x Lavval] Amethyst Chips Bottle '],
#  ['JS IG LIVE'],
#  ['[Jamstones x Lavval] Solitaire Crystal Necklace [Choose from 20+ centerpieces] '],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['Confidence (Calmness, Confidence, Healing, Wisdom)'],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['Delphin (Calmness, Builds Trust, Courage and Confidence)'],
#  ['[Jamstones x Lavval] Solitaire Crystal Necklace [Choose from 20+ centerpieces] ',
#   '[Jamstones x Lavval] DAINTY Crystal Bracelets ( Cool ) '],
#  ['Selenite Tower Small',
#   'Nebula ( Anti-Evil Eye, Protection and Wealth)',
#   'Atlantis (Luck, Love, Protection, Calmness and Healing'],
#  ['Healing Crystal Trees - Amethyst'],
#  ['[Jamstones x Lavval] Selenite Crystal Unicorn, Totoro, Nian (Wealth Lion), Hello Kitty Crystal '],
#  ['[Jamstones x Lavval] Jewel in A Box RESTOCKED 4 Crystal Bracelet [Wisdom] '],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['custom jade bracelet'],
#  ['Mermaid Dream Crystal Earrings (Madeat6pm x Jam.Stones Special Collaboration ) - Strawberry Quartz'],
#  ['Bloodstone Heart ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['[Jamstones x Lavval] Lyra Crystal Bracelet [Healing,Positivity,Wisdom,Wealth] '],
#  ['[Jamstones x NewageFSG SG LOCAL] Sea Salt '],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['[Jamstones x Lavval] Crystal Drop Earrings 2 pairs for $15 (UP $20) ',
#   '[Jamstones x Lavval] Solitaire Crystal Ring '],
#  ['[Jamstones x Lavval] Crystal Stacker Bracelet - Pastel Series '],
#  ['JS IG LIVE'],
#  ['[Jamstones x Lavval] Healing Crystal Tree ',
#   '[Jamstones x Lavval] Healing Crystal Tree ',
#   '[Jamstones x Lavval ] Selenite Tray ',
#   '[Jamstones x NewageFSG SG LOCAL] Clear Quartz Crystal Tumble (Clarity and Healing) '],
#  ['[Jamstones x Lavval] Sugar and Spice (Love, Weight-Loss and Wisdom) ',
#   '[Jamstones x Lavval] Crystal Candy Bracelet '],
#  ['[Jamstones x Lavval] Dainty Bracelet V2 ',
#   '[Jamstones x Lavval] Dainty Bracelet V2 '],
#  ['JS IG LIVE'],
#  ['[Jamstones x Lavval] Moonstone Rosie Bracelet '],
#  ['[Jamstones x Lavval] Jupiter (Wealth, Confidence and Harmony) '],
#  ['[Jamstones x Lavval] Crystal Magical Unicorn [Love,Wealth] ',
#   '[Jamstones x Lavval] Crystal Magical Unicorn [Love,Wealth] '],
#  ['Ig live'],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['[Jamstones x Lavval] Selenite Cleansing Kit ',
#   '[Jamstones x Lavval ] Selenite Tray ',
#   '[Jamstones x NewageFSG SG LOCAL] Sea Salt '],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['js ig live'],
#  ['JS IG LIVE'],
#  ['Premium Crystal Heart Stacker Series - Strawberry Quartz',
#   'Premium Crystal Heart Stacker Series - Kyanite'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['IG LIVE'],
#  ['IG LIVE'],
#  ['Charm Stacker Crystal Bracelet - Strawberry Quartz (Positivity)',
#   'Candice ( Strawberry Quartz)',
#   'Crystal Bag Charm - 4. Love'],
#  ['IG LIVE'],
#  ['JS IG LIVE'],
#  ['IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE', 'js ig live'],
#  ['JS IG LIVE'],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['JS IG LIVE'],
#  ['LUCKY RECHARGER BAG CHARM/KEY CHAIN'],
#  ['IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG Live'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE / SHOPEE LIVE pre 12.12 / 11.11'],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['[Jamstones x NewageFSG SG LOCAL] Amazonite Crystal Tumble (Mental-Healing and Positivity) '],
#  ['JS IG LIVE'],
#  ['JS IG LIVE'],
#  ['Premium Crystal Heart Stacker Series - Strawberry Quartz',
#   'Premium Crystal Heart Stacker Series - Kyanite'],
#  ['JS IG LIVE'],
#  ['Gift Orders'],
#  ['[Jamstones x Lavval] White Sage Pack ',
#   '[Jamstones x Lavval] White Sage Pack '],
#  ['[Jamstones x Lavval] White Sage Pack ',
#   '[Jamstones x Lavval] White Sage Pack '],
#  ['Auburn *Geometric Crystal contains surface marks/potholes* (Anti- Evil eye and Positivity)'],
#  ['[Jamstones x Lavval] Healing Crystal Tree ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm ',
#   '[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['Ametrine ring', 'Calmness shopee bracelet'],
#  ['[Jamstones x Lavval] Rosie Charm ',
#   '[Jamstones x Lavval] Rosie Charm ',
#   'Over the Rainbow stacker pearl'],
#  ['[Jamstones x Lavval] Dena Crystal Bracelet [ Calmness, Protection and Growth] 8.8 ',
#   'Minty( Love, Weight-Loss and Wisdom) '],
#  ['[Jamstones x Lavval] Dazzling Rose Quartz Earrings ',
#   'Milan ( Career, Wealth, Happiness and Confidence)',
#   '[Jamstones x Lavval] Strength  - Shopee Exclusive Crystal Bracelet [Strength,Wisdom] '],
#  ['[Jamstones x Lavval] Rosie Charm ', '[Jamstones x Lavval ] Selenite Tray '],
#  ['[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) '],
#  ['Minty( Love, Weight-Loss and Wisdom) '],
#  ['[Jamstones x Lavval ] Selenite Tray '],
#  ['[Jamstones x Lavval] Strawberry Quartz Chips Bottle ',
#   '[Jamstones x Lavval] Miffy Rabbit Crystal Resin '],
#  ['[Jamstones x Lavval] Rose Gold Bag Charm '],
#  ['Lepidolite Tumble (Healing and Positivity)',
#   'Sodalite Tumble (Anti-Confusion and Calmness)',
#   'Howlite Tumble (Calmness and Anti-Insomnia)',
#   'Que Sera Sera Tumble (Positivity and Revitalise)',
#   '[Jamstones x NewageFSG SG LOCAL] Rhodonite Crystal Tumble (Healing and Clarity) ',
#   'Chevron Amethyst Tumble (Concentration and Manifestation)',
#   '[Jamstones x NewageFSG SG LOCAL] Amazonite Crystal Tumble (Mental-Healing and Positivity) ',
#   '[Jamstones x NewageFSG SG LOCAL] Black Tourmaline Crystal Tumble (Protection and Anti-Stress) ',
#   '[Jamstones x NewageFSG SG LOCAL] Bronzite Tumble ( Anti- Evil Eye and Protection) ',
#   'Green Fluorite Tumble (Anti-Stress and Protection)'],
#  ['[Jamstones x Lavval] Trinity (Protection, Positivity and Grounding) '],
#  ['[Jamstones x Lavval] Estella Crystal Bracelet [Love,Wisdom] ',
#   'Minty( Love, Weight-Loss and Wisdom) '],
#  ['[Jamstones x Lavval] Selenite Cleansing Kit ',
#   '[Jamstones x Lavval ] Selenite Tray ',
#   '[Jamstones x NewageFSG SG LOCAL] Sea Salt '],
#  ['[Jamstones x Lavval] Wisdom  - Shopee Exclusive Crystal Bracelet [Wisdom,Wealth
#   '[Jamstones x Lavval] Lucky Clover | Heart Rose Quartz Bowl ',
#   '[Jamstones x Lavval] Amethyst Eye Pillow ',
#   '[Jamstones x Lavval] Amethyst Eye Pillow '],
#  ['[Jamstones x Lavval] DAINTY Crystal Bracelets ( Warm ) '],
#  ['[Jamstones x Lavval ] Selenite Tray '],
#  ['[Jamstones x Lavval] Dazzling Rose Quartz Earrings '],
#  ['[Jamstones x Lavval] Crystal Magical Unicorn [Love,Wealth] ',
#   '[Jamstones x NewageFSG] Bloodstone Mini Pointer ',
#   '[Jamstones x Lavval] Charoite Chips Bottle '],
#  ['[Jamstones x Lavval] [JS x LV] Karla  * Jade Stacker* Crystal Bracelet [Luck,Wisdom] '],
#  ['[Jamstones x Lavval] Selenite Tower Crystal Lamp ',
#   '[Jamstones x NewageFSG] Mini Green Angelite Pointer '],
#  ['[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) ',
#   'Mermaid Dream Crystal Earrings (Madeat6pm x Jam.Stones Special Collaboration ) - Lavender Amethyst'],
#  ['[Jamstones x Lavval] Sugar & Spice Necklace (Love, Wealth and Weight-Loss) ',
#   'Mermaid Dream Crystal Earrings (Madeat6pm x Jam.Stones Special Collaboration ) - Lavender Amethyst'],
#  ['Lepidolite Tumble (Healing and Positivity)'],
#  ['[Jamstones x Lavval] Healing Crystal Tree '],
#  ['Rosie ( Love, Weight-Loss and Wisdom)'],
#  ['[Jamstones x Lavval] Strength  - Shopee Exclusive Crystal Bracelet [Strength,Wisdom] '],
#  ['Lyra (Career, Wealth, Self confidence, and Healing) - 17mm'],
#  ['[Jamstones x Lavval] White Sage Pack ',
#   '[Jamstones x Lavval] White Sage Pack '],
#  ['[Jamstones x Lavval] Miffy Rabbit Crystal Resin '],
#  ['[Jamstones x Lavval] Crystal Candy Bracelet '],
#  ...]

# %%
categories_per_transaction_list
# Out:
# [['bag charm', 'bag charm'],
#  ['bag charm', 'bag charm'],
#  ['bag charm', 'bag charm'],
#  ['necklace', 'necklace', 'bracelet'],
#  ['others', 'necklace', 'necklace'],
#  ['others', 'others'],
#  ['tree'],
#  ['bracelet'],
#  ['necklace', 'tree'],
#  ['tree', 'others'],
#  ['bracelet', 'bracelet'],
#  ['bottle', 'bag charm'],
#  ['bracelet', 'bracelet'],
#  ['bracelet'],
#  ['others'],
#  ['ring', 'charm', 'kit', 'kit'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['lamp', 'others'],
#  ['pointer'],
#  ['bracelet'],
#  ['bag charm'],
#  ['others'],
#  ['bracelet', 'others'],
#  ['bag'],
#  ['earrings'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['kit'],
#  ['kit', 'kit'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['necklace'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['tower', 'bracelet'],
#  ['bracelet', 'bracelet'],
#  ['tumble',
#   'tumble',
#   'tumble',
#   'others',
#   'tumble',
#   'tumble',
#   'pointer',
#   'tumble',
#   'tumble'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bag', 'bag', 'bag', 'bag', 'bag'],
#  ['others'],
#  ['tumble', 'tumble', 'tumble', 'tumble', 'tumble', 'tumble'],
#  ['earrings', 'earrings'],
#  ['others', 'tumble', 'tumble'],
#  ['bracelet', 'bracelet'],
#  ['necklace', 'earrings'],
#  ['others'],
#  ['others'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['necklace', 'necklace'],
#  ['bag charm'],
#  ['necklace'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['bracelet'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['necklace', 'necklace'],
#  ['bracelet'],
#  ['bracelet'],
#  ['tumble'],
#  ['necklace'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bag charm'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet', 'bag charm'],
#  ['bracelet', 'bracelet', 'necklace'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bag charm', 'bag charm'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['earrings'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bracelet'],
#  ['bracelet', 'lamp'],
#  ['bracelet'],
#  ['others'],
#  ['ring'],
#  ['others'],
#  ['others', 'others', 'others'],
#  ['others', 'pointer'],
#  ['lamp', 'others'],
#  ['bracelet'],
#  ['tree', 'tree', 'others', 'others'],
#  ['pointer', 'bracelet', 'others'],
#  ['bracelet', 'others'],
#  ['bracelet', 'others'],
#  ['others', 'earrings'],
#  ['bracelet', 'bracelet'],
#  ['bracelet', 'others'],
#  ['bracelet'],
#  ['bracelet', 'tree'],
#  ['bag charm'],
#  ['necklace', 'others', 'others'],
#  ['tree'],
#  ['bag charm'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bag charm'],
#  ['others'],
#  ['necklace', 'earrings', 'ring'],
#  ['bracelet', 'others', 'others'],
#  ['others', 'others', 'bracelet'],
#  ['others', 'others', 'bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bag charm'],
#  ['pendant'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['necklace', 'bracelet', 'bracelet'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['others'],
#  ['earrings', 'earrings', 'others'],
#  ['others'],
#  ['others', 'necklace', 'necklace'],
#  ['bracelet', 'others'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['bag charm'],
#  ['ring', 'ring'],
#  ['bracelet'],
#  ['bag charm'],
#  ['tree'],
#  ['others', 'bracelet', 'others'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['ring'],
#  ['ring'],
#  ['others'],
#  ['others', 'others', 'ring'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['others', 'tree'],
#  ['bracelet', 'bracelet'],
#  ['bracelet'],
#  ['necklace', 'bracelet', 'bracelet'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['ring'],
#  ['others'],
#  ['pendant', 'earrings', 'earrings', 'others', 'others', 'others'],
#  ['pointer', 'others'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'others'],
#  ['necklace'],
#  ['bag charm'],
#  ['others'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'solitaire',
#   'bracelet',
#   'bracelet',
#   'earrings',
#   'earrings',
#   'earrings',
#   'earrings',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['bag charm'],
#  ['pointer'],
#  ['bracelet'],
#  ['necklace', 'bag charm'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet'],
#  ['tumble'],
#  ['others', 'others', 'others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet'],
#  ['bracelet', 'others'],
#  ['others'],
#  ['tumble'],
#  ['bag charm'],
#  ['bag charm'],
#  ['others'],
#  ['tree'],
#  ['bracelet'],
#  ['necklace'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['necklace', 'bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bracelet'],
#  ['necklace', 'bracelet'],
#  ['kit'],
#  ['bracelet'],
#  ['necklace', 'solitaire', 'others'],
#  ['bracelet'],
#  ['bracelet', 'others'],
#  ['charm'],
#  ['bag charm'],
#  ['necklace'],
#  ['bracelet', 'bag charm'],
#  ['bracelet'],
#  ['necklace'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['others'],
#  ['others'],
#  ['necklace'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet', 'others'],
#  ['ring'],
#  ['others', 'pointer'],
#  ['bracelet'],
#  ['bracelet', 'others'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bag charm'],
#  ['others', 'tree'],
#  ['bag charm'],
#  ['bag charm'],
#  ['tumble', 'bag charm', 'bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm'],
#  ['others'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['bracelet', 'bag charm'],
#  ['bracelet'],
#  ['bracelet'],
#  ['others', 'bracelet', 'necklace', 'necklace'],
#  ['tumble'],
#  ['bracelet'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['bag charm', 'bag charm'],
#  ['others'],
#  ['bracelet'],
#  ['bag charm', 'others', 'bag charm'],
#  ['ring'],
#  ['tree', 'tree', 'tree'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['tree', 'bag charm'],
#  ['bag charm'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['necklace', 'bag charm'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['bracelet'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['bag charm'],
#  ['bag charm', 'bag charm'],
#  ['others'],
#  ['bracelet'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm'],
#  ['bracelet', 'bracelet'],
#  ['others', 'others'],
#  ['others'],
#  ['tree'],
#  ['others'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['bracelet'],
#  ['ring'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bracelet',
#   'bracelet',
#   'others',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm'],
#  ['bracelet', 'necklace', 'others'],
#  ['tree'],
#  ['bag charm', 'bag charm'],
#  ['necklace'],
#  ['bag charm'],
#  ['others'],
#  ['kit'],
#  ['bracelet'],
#  ['others'],
#  ['others', 'bracelet', 'bracelet'],
#  ['necklace'],
#  ['bag charm'],
#  ['bracelet'],
#  ['bag charm'],
#  ['solitaire'],
#  ['earrings', 'bracelet'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['necklace', 'bottle', 'bottle', 'bottle'],
#  ['others'],
#  ['necklace'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['others'],
#  ['necklace', 'bracelet'],
#  ['tower', 'others', 'others'],
#  ['tree'],
#  ['kit'],
#  ['bracelet'],
#  ['bag charm', 'bag charm'],
#  ['bracelet'],
#  ['earrings'],
#  ['others', 'bag charm', 'bag charm'],
#  ['bracelet'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['earrings', 'ring'],
#  ['bracelet'],
#  ['others'],
#  ['tree', 'tree', 'others', 'tumble'],
#  ['others', 'bracelet'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['kit', 'others', 'others'],
#  ['bag charm'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bracelet', 'others', 'bag charm'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['bag charm'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['tumble'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['tree', 'bag charm', 'bag charm'],
#  ['ring', 'bracelet'],
#  ['charm', 'charm', 'others'],
#  ['bracelet', 'others'],
#  ['earrings', 'others', 'bracelet'],
#  ['charm', 'others'],
#  ['necklace'],
#  ['others'],
#  ['others'],
#  ['bottle', 'others'],
#  ['bag charm'],
#  ['tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble'],
#  ['others'],
#  ['bracelet', 'others'],
#  ['kit', 'others', 'others'],
#  ['bracelet', 'bracelet'],
#  ['charm', 'others'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bracelet'],
#  ['necklace'],
#  ['others'],
#  ['others'],
#  ['earrings', 'bracelet'],
#  ['necklace'],
#  ['others'],
#  ['bracelet', 'bracelet', 'bag charm', 'bag charm'],
#  ['bottle', 'bottle', 'bottle'],
#  ['necklace'],
#  ['others', 'others'],
#  ['lamp'],
#  ['lamp'],
#  ['necklace'],
#  ['bag charm'],
#  ['bracelet'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet', 'others', 'others', 'others'],
#  ['bracelet'],
#  ['others', 'others', 'others'],
#  ['bag charm'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bag charm'],
#  ['solitaire', 'earrings'],
#  ['bracelet'],
#  ['bottle', 'bottle'],
#  ['others', 'bag charm'],
#  ['others', 'necklace'],
#  ['others'],
#  ['others', 'others', 'others', 'others', 'others', 'others', 'others'],
#  ['earrings'],
#  ['others', 'bottle'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bag charm'],
#  ['others'],
#  ['others'],
#  ['necklace'],
#  ['others'],
#  ['lamp', 'others'],
#  ['bracelet', 'bracelet', 'others'],
#  ['others'],
#  ['bracelet'],
#  ['charm', 'charm', 'charm', 'charm'],
#  ['earrings'],
#  ['charm', 'charm', 'charm', 'charm'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['others', 'necklace'],
#  ['others', 'others', 'others', 'earrings', 'others', 'others', 'others'],
#  ['others', 'bottle', 'bottle'],
#  ['others'],
#  ['tree'],
#  ['bracelet', 'bracelet', 'bracelet', 'bracelet'],
#  ['others'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['tower', 'necklace', 'tree', 'tree', 'others', 'pointer'],
#  ['lamp', 'others'],
#  ['bracelet', 'bag charm'],
#  ['bracelet'],
#  ['necklace', 'necklace', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bracelet', 'bag charm'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet', 'others', 'bag charm', 'bag charm', 'bag charm'],
#  ['kit'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bracelet'],
#  ['earrings'],
#  ['lamp'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['others'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['tree', 'others', 'ring'],
#  ['necklace'],
#  ['bracelet', 'bracelet'],
#  ['necklace'],
#  ['others'],
#  ['others'],
#  ['lamp'],
#  ['earrings'],
#  ['earrings', 'pendant'],
#  ['others'],
#  ['lamp', 'bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['kit'],
#  ['bracelet'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['bracelet', 'bracelet'],
#  ['tower', 'others', 'others', 'kit'],
#  ['bracelet', 'bracelet'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['necklace'],
#  ['others'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['others'],
#  ['necklace', 'necklace'],
#  ['tree'],
#  ['bag charm', 'bag charm'],
#  ['kit'],
#  ['kit'],
#  ['earrings', 'earrings', 'earrings', 'others'],
#  ['others', 'others', 'others'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['bracelet', 'pointer'],
#  ['bag charm'],
#  ['others'],
#  ['bracelet'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['others', 'others'],
#  ['ring'],
#  ['bag charm', 'bag charm'],
#  ['necklace'],
#  ['bag charm'],
#  ['others'],
#  ['tree'],
#  ['others'],
#  ['bag', 'bag', 'bag charm', 'bag charm'],
#  ['kit', 'kit', 'kit'],
#  ['others'],
#  ['others'],
#  ['necklace', 'bag charm'],
#  ['bag charm'],
#  ['tree', 'tree'],
#  ['bag charm'],
#  ['others'],
#  ['others'],
#  ['hedgehog', 'kit', 'others', 'bag', 'bag'],
#  ['others', 'others', 'others'],
#  ['bag charm'],
#  ['bag charm'],
#  ['bag charm'],
#  ['bag', 'others', 'kit'],
#  ['bag charm'],
#  ['bracelet', 'earrings'],
#  ['bag charm'],
#  ['bag'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['bag charm'],
#  ['bag charm', 'bag charm'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['charm', 'bracelet'],
#  ['bag charm'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['bag charm', 'bag charm'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['bag charm', 'bag charm'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bracelet'],
#  ['bag charm', 'bag charm'],
#  ['tree'],
#  ['others', 'others', 'others', 'others'],
#  ['bag charm', 'bag charm', 'bag charm', 'bag charm'],
#  ['charm'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'bracelet', 'bracelet', 'bracelet'],
#  ['others'],
#  ['bag charm', 'bag charm'],
#  ['bag charm', 'bag charm'],
#  ['bag charm'],
#  ['bag charm', 'bag charm'],
#  ['solitaire'],
#  ['bag charm', 'bag charm'],
#  ['bag charm'],
#  ['bracelet', 'bracelet'],
#  ['bag charm', 'bag charm'],
#  ['bag charm'],
#  ['bag charm'],
#  ['bracelet'],
#  ['bag charm'],
#  ['others', 'others'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['earrings'],
#  ['bag charm', 'bag charm'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'bag charm', 'bracelet'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['solitaire'],
#  ['others'],
#  ['lamp', 'others'],
#  ['ring', 'solitaire', 'others', 'bracelet', 'bracelet', 'ring'],
#  ['bracelet', 'bracelet'],
#  ['bag', 'others'],
#  ['earrings'],
#  ['bracelet'],
#  ['bag', 'bag', 'bag'],
#  ['others'],
#  ['bag', 'others'],
#  ['others'],
#  ['tree', 'tree'],
#  ['others', 'others'],
#  ['bracelet', 'bag charm'],
#  ['others', 'others', 'others'],
#  ['ring'],
#  ['bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm',
#   'bag charm'],
#  ['bracelet'],
#  ['bracelet'],
#  ['ring'],
#  ['bracelet'],
#  ['others', 'others'],
#  ['necklace', 'ring'],
#  ['others'],
#  ['others'],
#  ['bracelet', 'tumble', 'tumble', 'tumble', 'bracelet'],
#  ['necklace'],
#  ['bracelet'],
#  ['tree'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet', 'others'],
#  ['bracelet', 'tumble', 'tumble', 'tumble', 'tumble'],
#  ['others'],
#  ['others', 'others'],
#  ['bottle', 'bottle', 'bottle', 'others'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bag charm'],
#  ['bracelet'],
#  ['others', 'bag'],
#  ['ring'],
#  ['others'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['others', 'ring'],
#  ['others', 'others'],
#  ['earrings'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['others', 'others', 'others', 'others', 'others', 'others'],
#  ['others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['necklace', 'kit'],
#  ['others',
#   'tower',
#   'pointer',
#   'pointer',
#   'pointer',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble',
#   'tumble'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['tree'],
#  ['bracelet'],
#  ['bag charm', 'bag charm', 'bag charm'],
#  ['bag', 'bag', 'bag'],
#  ['bracelet'],
#  ['others', 'earrings', 'earrings', 'earrings'],
#  ['others', 'others'],
#  ['bag charm'],
#  ['ring'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bracelet'],
#  ['tree', 'others'],
#  ['kit', 'others', 'kit'],
#  ['others'],
#  ['ring'],
#  ['necklace'],
#  ['necklace', 'necklace'],
#  ['others'],
#  ['ring'],
#  ['others', 'others'],
#  ['others', 'others', 'others'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'bag', 'bag'],
#  ['bracelet'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['ring'],
#  ['ring'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'others'],
#  ['ring', 'ring'],
#  ['bracelet'],
#  ['bag', 'others'],
#  ['others'],
#  ['necklace'],
#  ['bracelet'],
#  ['others', 'tumble', 'tumble', 'kit'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['others', 'necklace', 'necklace', 'necklace', 'necklace'],
#  ['chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip',
#   'chip'],
#  ['necklace', 'bracelet'],
#  ['bracelet'],
#  ['ring'],
#  ['bottle', 'bottle', 'bottle', 'bottle'],
#  ['others', 'others'],
#  ['bracelet'],
#  ['bag', 'bag'],
#  ['necklace'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'necklace',
#   'others'],
#  ['necklace'],
#  ['others'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others', 'bracelet'],
#  ['others', 'others'],
#  ['bracelet', 'bracelet'],
#  ['others', 'others'],
#  ['others', 'others', 'others', 'others', 'others'],
#  ['others'],
#  ['others',
#   'display',
#   'others',
#   'bracelet',
#   'bracelet',
#   'others',
#   'others',
#   'others'],
#  ['bracelet'],
#  ['earrings'],
#  ['bracelet'],
#  ['others', 'others'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['others', 'bag', 'others', 'others'],
#  ['earrings'],
#  ['others', 'bracelet'],
#  ['bag', 'bag', 'bag', 'bag'],
#  ['others'],
#  ['bracelet', 'bracelet'],
#  ['bag', 'others'],
#  ['necklace'],
#  ['bracelet'],
#  ['necklace', 'necklace'],
#  ['necklace', 'bracelet'],
#  ['others', 'others'],
#  ['earrings', 'solitaire', 'earrings', 'solitaire'],
#  ['bag', 'bag', 'bag'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['necklace', 'necklace', 'necklace', 'others', 'others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bag'],
#  ['kit', 'kit'],
#  ['others'],
#  ['ring'],
#  ['kit'],
#  ['tumble', 'tumble'],
#  ['bracelet'],
#  ['bracelet', 'bracelet', 'bracelet', 'necklace'],
#  ['others', 'others', 'bag'],
#  ['charm', 'tumble'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bag'],
#  ['necklace'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['earrings', 'earrings'],
#  ['others'],
#  ['others'],
#  ['earrings'],
#  ['bracelet'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['bag'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others', 'necklace'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['necklace'],
#  ['bracelet'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['lamp', 'kit'],
#  ['others'],
#  ['others'],
#  ['bag', 'bag'],
#  ['others', 'earrings'],
#  ['bag', 'others'],
#  ['necklace', 'charm'],
#  ['others'],
#  ['others'],
#  ['bracelet', 'bracelet'],
#  ['bag', 'bag'],
#  ['bracelet'],
#  ['bag'],
#  ['others'],
#  ['bracelet', 'bracelet'],
#  ['bracelet', 'bracelet'],
#  ['bottle'],
#  ['bracelet', 'bracelet'],
#  ['bag', 'others', 'others'],
#  ['others', 'others'],
#  ['bag', 'others'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['others', 'bag'],
#  ['others'],
#  ['others'],
#  ['others', 'earrings'],
#  ['others', 'others', 'others'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['others', 'others', 'others', 'others'],
#  ['others', 'others', 'bracelet'],
#  ['others', 'others'],
#  ['others'],
#  ['others', 'earrings', 'others', 'others'],
#  ['others'],
#  ['others'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['earrings', 'earrings', 'necklace'],
#  ['bag'],
#  ['bracelet', 'bracelet'],
#  ['bag', 'kit'],
#  ['others', 'others', 'lamp', 'others'],
#  ['necklace', 'others'],
#  ['bracelet'],
#  ['bag'],
#  ['bracelet'],
#  ['ring'],
#  ['bag', 'bag'],
#  ['bag', 'bag'],
#  ['bag'],
#  ['bag', 'bag', 'bag', 'bag'],
#  ['necklace', 'others', 'earrings'],
#  ['bag'],
#  ['others'],
#  ['bag'],
#  ['lamp'],
#  ['bottle'],
#  ['bag', 'kit'],
#  ['others', 'others'],
#  ['others', 'others'],
#  ['earrings', 'earrings', 'ring', 'ring', 'ring', 'ring'],
#  ['necklace'],
#  ['tree'],
#  ['tumble', 'tumble'],
#  ['others', 'kit'],
#  ['others'],
#  ['ring', 'ring'],
#  ['earrings', 'tumble'],
#  ['ring'],
#  ['necklace'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bracelet'],
#  ['others'],
#  ['ring', 'ring'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet', 'pointer'],
#  ['pendant'],
#  ['necklace'],
#  ['bracelet'],
#  ['others'],
#  ['necklace', 'necklace'],
#  ['bottle', 'bottle'],
#  ['tree'],
#  ['others', 'others'],
#  ['others'],
#  ['earrings'],
#  ['others', 'lamp', 'others'],
#  ['bracelet'],
#  ['earrings', 'earrings'],
#  ['earrings'],
#  ['necklace', 'necklace'],
#  ['others', 'others'],
#  ['others', 'tumble', 'others', 'others', 'kit'],
#  ['others'],
#  ['others', 'others'],
#  ['bracelet', 'lamp', 'bracelet'],
#  ['necklace'],
#  ['necklace'],
#  ['bracelet'],
#  ['bag charm'],
#  ['bracelet', 'others'],
#  ['bracelet'],
#  ['ring'],
#  ['bottle'],
#  ['necklace'],
#  ['others'],
#  ['necklace', 'necklace'],
#  ['kit', 'kit'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['tumble'],
#  ['bracelet'],
#  ['others'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others',
#   'others'],
#  ['others'],
#  ['bracelet', 'others'],
#  ['earrings'],
#  ['bracelet', 'bracelet', 'bracelet'],
#  ['bracelet', 'bracelet', 'others'],
#  ['bracelet'],
#  ['others'],
#  ['others'],
#  ['pointer', 'pointer'],
#  ['bracelet'],
#  ['bracelet', 'earrings', 'bracelet'],
#  ['tree', 'tree'],
#  ['bracelet'],
#  ['bracelet', 'bracelet'],
#  ['others'],
#  ['lamp'],
#  ['others'],
#  ['bracelet'],
#  ['bracelet'],
#  ['bracelet'],
#  ['necklace'],
#  ['bracelet'],
#  ['hedgehog', 'bottle'],
#  ['lamp'],
#  ['bracelet', 'others', 'others', 'others'],
#  ['bracelet'],
#  ['others'],
#  ['earrings'],
#  ['others', 'pointer', 'bottle'],
#  ['bracelet'],
#  ['lamp', 'pointer'],
#  ['necklace', 'earrings'],
#  ['necklace', 'earrings'],
#  ['tumble'],
#  ['tree'],
#  ['others'],
#  ['bracelet'],
#  ['others'],
#  ['others', 'others'],
#  ['others'],
#  ['bracelet'],
#  ...]

# %%
# !pip install mlxtend

# %% [markdown]
# ### MBA Using Items

# %%
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(items_per_transaction_list).transform(items_per_transaction_list)
te_ary
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
mba_df = pd.DataFrame(te_ary, columns=te.columns_)
mba_df.describe()
# Out:
#        $4 courier for JS5331 $50 gift voucher  \
# count                  13273            13273
# unique                     2                2
# top                    False            False
# freq                   13272            13272
#
#        *14mmLavender rose quartz solitaire  \
# count                                13273
# unique                                   2
# top                                  False
# freq                                 13272
#
#        *DIRECT IMPORT from South America Palo Santo Wood Bundle   \
# count                                               13273
# unique                                                  2
# top                                                 False
# freq                                                13271
#
#        *PREMIUM* Asterism Lavender Rose Quartz 40mm Sphere  \
# count                                               13273
# unique                                                  2
# top                                                 False
# freq                                                13272
#
#        *PREMIUM* Asterism Lavender Rose Quartz 72mm Sphere  \
# count                                               13273
# unique                                                  2
# top                                                 False
# freq                                                13272
#
#        *PREMIUM* Black Tourmalinated Quartz Tumble *PREMIUM* Citrine Chips  \
# count                                        13273                   13273
# unique                                           2                       2
# top                                          False                   False
# freq                                         13270                   13251
#
#        *PREMIUM* Fluorite 6mm Bracelet  \
# count                            13273
# unique                               2
# top                              False
# freq                             13271
#
#        *PREMIUM* Fluorite Beads (20cm bracelet top-up)  ...  \
# count                                            13273  ...
# unique                                               2  ...
# top                                              False  ...
# freq                                             13272  ...
#
#        ✨PROMO✨ Anti - Radiation Kit - Yes! I wish to add in the Labrdorite Crystal Grip  \
# count                                               13273
# unique                                                  2
# top                                                 False
# freq                                                13272
#
#        万事如意 (Success in everything) 和气生财 (Harmony brings wealth)   心想事成  \
# count                         13273                        13273  13273
# unique                            2                            2      2
# top                           False                        False  False
# freq                          13249                        13268  13272
#
#        心想事成 (Wish come true) 心想事成 (Wish come true) - 14mm  \
# count                  13273                        13273
# unique                     2                            2
# top                    False                        False
# freq                   13272                        13266
#
#        心想事成 (Wish come true) - 16mm 恭喜发财 [Happiness and Prosperity]  \
# count                         13273                           13273
# unique                            2                               2
# top                           False                           False
# freq                          13270                           13267
#
#        財源滾滾 [Endless Wealth] 财源广进  (Endless fortune)
# count                  13273                   13273
# unique                     2                       2
# top                    False                   False
# freq                   13231                   13268
#
# [4 rows x 6129 columns]

# %%
from mlxtend.frequent_patterns import apriori

#Now, let us return the items and itemsets with at least 1% support:
ap_items = mlxtend.frequent_patterns.apriori(mba_df, min_support = 0.01, use_colnames = True)
ap_items
# Out:
#     support                                      itemsets
# 0  0.012808           (Wealth Magnet Bottle (U.P.$3.90) )
# 1  0.012733   ([Jamstones x Lavval] Amethyst Eye Pillow )
# 2  0.011753  ([Jamstones x Lavval] Healing Crystal Tree )

# %%
rules_items=mlxtend.frequent_patterns.association_rules(
ap_items, metric="confidence",min_threshold=0,support_only=False)
rules_items
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
frequent_itemsets = apriori(mba_df, min_support = 0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                                      itemsets  length
# 0  0.012808           (Wealth Magnet Bottle (U.P.$3.90) )       1
# 1  0.012733   ([Jamstones x Lavval] Amethyst Eye Pillow )       1
# 2  0.011753  ([Jamstones x Lavval] Healing Crystal Tree )       1

# %%
# getting th item sets with length = 2 and support more han 1%

frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length]
# Index: []

# %% [markdown]
# ### MBA using categories

# %%
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary2 = te.fit(categories_per_transaction_list).transform(categories_per_transaction_list)
te_ary2
# Out:
# array([[False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        ...,
#        [False, False, False, ...,  True, False,  True],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
mba_df2 = pd.DataFrame(te_ary2, columns=te.columns_)
mba_df2.describe()
# Out:
#           bag bag charm   bead bottle bracelet  charm   chip display earrings  \
# count   13273     13273  13273  13273    13273  13273  13273   13273    13273
# unique      2         2      2      2        2      2      2       2        2
# top     False     False  False  False    False  False  False   False    False
# freq    13162     12919  12964  12759    10421  12994  13218   13265    12740
#
#        hedgehog  ... others pendant pendulum pointer  pouch   ring solitaire  \
# count     13273  ...  13273   13273    13273   13273  13273  13273     13273
# unique        2  ...      2       2        2       2      2      2         2
# top       False  ...   True   False    False   False  False  False     False
# freq      13223  ...   7342   12894    13242   12868  13104  12792     12763
#
#         tower   tree tumble
# count   13273  13273  13273
# unique      2      2      2
# top     False  False  False
# freq    12966  13003  12786
#
# [4 rows x 23 columns]

# %%
from mlxtend.frequent_patterns import apriori

#Now, let us return the items and itemsets with at least 5% support:
ap_categories = mlxtend.frequent_patterns.apriori(mba_df2, min_support = 0.01, use_colnames = True)
ap_categories
# Out:
#      support              itemsets
# 0   0.026671           (bag charm)
# 1   0.023280                (bead)
# 2   0.038725              (bottle)
# 3   0.214872            (bracelet)
# 4   0.021020               (charm)
# 5   0.040157            (earrings)
# 6   0.019061                 (kit)
# 7   0.027198                (lamp)
# 8   0.096813            (necklace)
# 9   0.553153              (others)
# 10  0.028554             (pendant)
# 11  0.030513             (pointer)
# 12  0.012733               (pouch)
# 13  0.036239                (ring)
# 14  0.038424           (solitaire)
# 15  0.023130               (tower)
# 16  0.020342                (tree)
# 17  0.036691              (tumble)
# 18  0.012883      (others, bottle)
# 19  0.011452  (necklace, bracelet)
# 20  0.053191    (others, bracelet)
# 21  0.014390    (others, earrings)
# 22  0.012205        (others, lamp)
# 23  0.033225    (others, necklace)
# 24  0.015294     (others, pointer)
# 25  0.011452        (ring, others)
# 26  0.016876   (others, solitaire)
# 27  0.012431       (others, tower)
# 28  0.018006      (others, tumble)

# %%
rules_categories = mlxtend.frequent_patterns.association_rules(
ap_categories, metric="confidence",min_threshold=0,support_only=False)
rules_categories
# Out:
#     antecedents  consequents  antecedent support  consequent support  \
# 0      (others)     (bottle)            0.553153            0.038725
# 1      (bottle)     (others)            0.038725            0.553153
# 2    (necklace)   (bracelet)            0.096813            0.214872
# 3    (bracelet)   (necklace)            0.214872            0.096813
# 4      (others)   (bracelet)            0.553153            0.214872
# 5    (bracelet)     (others)            0.214872            0.553153
# 6      (others)   (earrings)            0.553153            0.040157
# 7    (earrings)     (others)            0.040157            0.553153
# 8      (others)       (lamp)            0.553153            0.027198
# 9        (lamp)     (others)            0.027198            0.553153
# 10     (others)   (necklace)            0.553153            0.096813
# 11   (necklace)     (others)            0.096813            0.553153
# 12     (others)    (pointer)            0.553153            0.030513
# 13    (pointer)     (others)            0.030513            0.553153
# 14       (ring)     (others)            0.036239            0.553153
# 15     (others)       (ring)            0.553153            0.036239
# 16     (others)  (solitaire)            0.553153            0.038424
# 17  (solitaire)     (others)            0.038424            0.553153
# 18     (others)      (tower)            0.553153            0.023130
# 19      (tower)     (others)            0.023130            0.553153
# 20     (others)     (tumble)            0.553153            0.036691
# 21     (tumble)     (others)            0.036691            0.553153
#
#      support  confidence      lift  leverage  conviction
# 0   0.012883    0.023291  0.601434 -0.008538    0.984197
# 1   0.012883    0.332685  0.601434 -0.008538    0.669619
# 2   0.011452    0.118288  0.550503 -0.009351    0.890458
# 3   0.011452    0.053296  0.550503 -0.009351    0.954033
# 4   0.053191    0.096159  0.447517 -0.065667    0.868657
# 5   0.053191    0.247546  0.447517 -0.065667    0.593853
# 6   0.014390    0.026015  0.647830 -0.007823    0.985480
# 7   0.014390    0.358349  0.647830 -0.007823    0.696402
# 8   0.012205    0.022065  0.811265 -0.002839    0.994751
# 9   0.012205    0.448753  0.811265 -0.002839    0.810612
# 10  0.033225    0.060065  0.620426 -0.020327    0.960904
# 11  0.033225    0.343191  0.620426 -0.020327    0.680330
# 12  0.015294    0.027649  0.906141 -0.001584    0.997055
# 13  0.015294    0.501235  0.906141 -0.001584    0.895906
# 14  0.011452    0.316008  0.571286 -0.008594    0.653293
# 15  0.011452    0.020703  0.571286 -0.008594    0.984135
# 16  0.016876    0.030509  0.794022 -0.004378    0.991836
# 17  0.016876    0.439216  0.794022 -0.004378    0.796825
# 18  0.012431    0.022473  0.971629 -0.000363    0.999329
# 19  0.012431    0.537459  0.971629 -0.000363    0.966071
# 20  0.018006    0.032552  0.887204 -0.002289    0.995722
# 21  0.018006    0.490760  0.887204 -0.002289    0.877478

# %%
frequent_itemsets = apriori(mba_df2, min_support = 0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#      support              itemsets  length
# 0   0.026671           (bag charm)       1
# 1   0.023280                (bead)       1
# 2   0.038725              (bottle)       1
# 3   0.214872            (bracelet)       1
# 4   0.021020               (charm)       1
# 5   0.040157            (earrings)       1
# 6   0.019061                 (kit)       1
# 7   0.027198                (lamp)       1
# 8   0.096813            (necklace)       1
# 9   0.553153              (others)       1
# 10  0.028554             (pendant)       1
# 11  0.030513             (pointer)       1
# 12  0.012733               (pouch)       1
# 13  0.036239                (ring)       1
# 14  0.038424           (solitaire)       1
# 15  0.023130               (tower)       1
# 16  0.020342                (tree)       1
# 17  0.036691              (tumble)       1
# 18  0.012883      (others, bottle)       2
# 19  0.011452  (necklace, bracelet)       2
# 20  0.053191    (others, bracelet)       2
# 21  0.014390    (others, earrings)       2
# 22  0.012205        (others, lamp)       2
# 23  0.033225    (others, necklace)       2
# 24  0.015294     (others, pointer)       2
# 25  0.011452        (ring, others)       2
# 26  0.016876   (others, solitaire)       2
# 27  0.012431       (others, tower)       2
# 28  0.018006      (others, tumble)       2

# %%
# getting th item sets with length = 2 and support more han 10%

frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support              itemsets  length
# 18  0.012883      (others, bottle)       2
# 19  0.011452  (necklace, bracelet)       2
# 20  0.053191    (others, bracelet)       2
# 21  0.014390    (others, earrings)       2
# 22  0.012205        (others, lamp)       2
# 23  0.033225    (others, necklace)       2
# 24  0.015294     (others, pointer)       2
# 25  0.011452        (ring, others)       2
# 26  0.016876   (others, solitaire)       2
# 27  0.012431       (others, tower)       2
# 28  0.018006      (others, tumble)       2

# %%
# type of stone
# names (?) - confidence, wealth (???)

# %% [markdown]
# ## MBA Using Crystals

# %%
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary3 = te.fit(crystals_per_transaction_list).transform(crystals_per_transaction_list)
te_ary3
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
mba_df3 = pd.DataFrame(te_ary3, columns=te.columns_)
mba_df3.describe()
# Out:
#         agate amazonite  amber amethyst ametrine ammonite angelite apatite  \
# count   13273     13273  13273    13273    13273    13273    13273   13273
# unique      2         2      2        2        2        2        2       2
# top     False     False  False    False    False    False    False   False
# freq    12471     13159  13263    12564    13255    13270    13048   13238
#
#        aquamarine aragonite  ... sodalite sugilite sunstone tanzanite tektite  \
# count       13273     13273  ...    13273    13273    13273     13273   13273
# unique          2         2  ...        2        2        2         2       2
# top         False     False  ...    False    False    False     False   False
# freq        12951     13247  ...    13176    13269    13184     13250   13265
#
#        tiger's eye  topaz tourmaline turquoise zoisite
# count        13273  13273      13273     13273   13273
# unique           2      2          2         2       2
# top          False  False      False     False   False
# freq         13161  13242      13149     13269   13268
#
# [4 rows x 89 columns]

# %%
from mlxtend.frequent_patterns import apriori

#Now, let us return the items and itemsets with at least 5% support:
ap_crystals = mlxtend.frequent_patterns.apriori(mba_df3, min_support = 0.01, use_colnames = True)
ap_crystals
# Out:
#      support               itemsets
# 0   0.060423                (agate)
# 1   0.053417             (amethyst)
# 2   0.016952             (angelite)
# 3   0.024260           (aquamarine)
# 4   0.010548           (aventurine)
# 5   0.010548     (black tourmaline)
# 6   0.034581              (citrine)
# 7   0.015144         (clear quartz)
# 8   0.016650             (fluorite)
# 9   0.053191                 (jade)
# 10  0.016952          (labradorite)
# 11  0.010774         (lapis lazuli)
# 12  0.011904              (larimar)
# 13  0.044376            (moonstone)
# 14  0.014013             (obsidian)
# 15  0.693136               (others)
# 16  0.063437          (rose quartz)
# 17  0.078279             (selenite)
# 18  0.025541        (others, agate)
# 19  0.023958     (others, amethyst)
# 20  0.016198      (citrine, others)
# 21  0.025767         (others, jade)
# 22  0.020869    (moonstone, others)
# 23  0.026143  (others, rose quartz)
# 24  0.036917     (others, selenite)

# %%
rules_crystals = mlxtend.frequent_patterns.association_rules(
ap_crystals, metric="confidence",min_threshold=0,support_only=False)
rules_crystals
# Out:
#       antecedents    consequents  antecedent support  consequent support  \
# 0        (others)        (agate)            0.693136            0.060423
# 1         (agate)       (others)            0.060423            0.693136
# 2        (others)     (amethyst)            0.693136            0.053417
# 3      (amethyst)       (others)            0.053417            0.693136
# 4       (citrine)       (others)            0.034581            0.693136
# 5        (others)      (citrine)            0.693136            0.034581
# 6        (others)         (jade)            0.693136            0.053191
# 7          (jade)       (others)            0.053191            0.693136
# 8     (moonstone)       (others)            0.044376            0.693136
# 9        (others)    (moonstone)            0.693136            0.044376
# 10       (others)  (rose quartz)            0.693136            0.063437
# 11  (rose quartz)       (others)            0.063437            0.693136
# 12       (others)     (selenite)            0.693136            0.078279
# 13     (selenite)       (others)            0.078279            0.693136
#
#      support  confidence      lift  leverage  conviction
# 0   0.025541    0.036848  0.609827 -0.016341    0.975522
# 1   0.025541    0.422693  0.609827 -0.016341    0.531543
# 2   0.023958    0.034565  0.647086 -0.013067    0.980474
# 3   0.023958    0.448519  0.647086 -0.013067    0.556435
# 4   0.016198    0.468410  0.675783 -0.007771    0.577256
# 5   0.016198    0.023370  0.675783 -0.007771    0.988520
# 6   0.025767    0.037174  0.698880 -0.011102    0.983365
# 7   0.025767    0.484419  0.698880 -0.011102    0.595180
# 8   0.020869    0.470289  0.678494 -0.009889    0.579303
# 9   0.020869    0.030109  0.678494 -0.009889    0.985290
# 10  0.026143    0.037717  0.594564 -0.017827    0.973272
# 11  0.026143    0.412114  0.594564 -0.017827    0.521978
# 12  0.036917    0.053261  0.680396 -0.017341    0.973574
# 13  0.036917    0.471607  0.680396 -0.017341    0.580749

# %%
frequent_itemsets = apriori(mba_df3, min_support = 0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#      support               itemsets  length
# 0   0.060423                (agate)       1
# 1   0.053417             (amethyst)       1
# 2   0.016952             (angelite)       1
# 3   0.024260           (aquamarine)       1
# 4   0.010548           (aventurine)       1
# 5   0.010548     (black tourmaline)       1
# 6   0.034581              (citrine)       1
# 7   0.015144         (clear quartz)       1
# 8   0.016650             (fluorite)       1
# 9   0.053191                 (jade)       1
# 10  0.016952          (labradorite)       1
# 11  0.010774         (lapis lazuli)       1
# 12  0.011904              (larimar)       1
# 13  0.044376            (moonstone)       1
# 14  0.014013             (obsidian)       1
# 15  0.693136               (others)       1
# 16  0.063437          (rose quartz)       1
# 17  0.078279             (selenite)       1
# 18  0.025541        (others, agate)       2
# 19  0.023958     (others, amethyst)       2
# 20  0.016198      (citrine, others)       2
# 21  0.025767         (others, jade)       2
# 22  0.020869    (moonstone, others)       2
# 23  0.026143  (others, rose quartz)       2
# 24  0.036917     (others, selenite)       2

# %%
# getting th item sets with length = 2 and support more han 10%

frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support               itemsets  length
# 18  0.025541        (others, agate)       2
# 19  0.023958     (others, amethyst)       2
# 20  0.016198      (citrine, others)       2
# 21  0.025767         (others, jade)       2
# 22  0.020869    (moonstone, others)       2
# 23  0.026143  (others, rose quartz)       2
# 24  0.036917     (others, selenite)       2
